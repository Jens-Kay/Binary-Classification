# %%
# !wget -c http://s3.amazonaws.com/content.udacity-data.com/nd089/Cat_Dog_data.zip
# Out:
# --2023-10-12 13:51:42--  http://s3.amazonaws.com/content.udacity-data.com/nd089/Cat_Dog_data.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.197.184, 52.217.168.144, 52.217.232.144, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.197.184|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 580495262 (554M) [application/zip]
# Saving to: ‘Cat_Dog_data.zip’
#
# Cat_Dog_data.zip    100%[===================>] 553.60M  53.1MB/s    in 10s
#
# 2023-10-12 13:51:53 (55.3 MB/s) - ‘Cat_Dog_data.zip’ saved [580495262/580495262]

# %%
import numpy as np
import random
import os
import matplotlib

# %%
from tensorflow.keras import layers
image_in = layers.Input(shape=(150,150,3))

# %%
x = layers.Conv2D(32, 3, activation='relu')(image_in)
x = layers.MaxPooling2D(2)(x)

# %%
x = layers.Conv2D(64, 3, activation='relu')(x)
x = layers.MaxPooling2D(2)(x)

# %%
x = layers.Flatten()(x)
x = layers.Dense(512,activation='relu')(x)

# %%
output = layers.Dense(1,activation='sigmoid')(x)

# %%
from tensorflow.keras.models import Model
my_model= Model(image_in,output)

# %%
from tensorflow.keras.optimizers import RMSprop
my_model.compile(loss='binary_crossentropy',optimizer=RMSprop(0.001),metrics=['acc'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
training_data = ImageDataGenerator(rescale=1./255)

# %%
import os
import zipfile
import requests
from tensorflow.keras.preprocessing.image import ImageDataGenerator

url = "http://s3.amazonaws.com/content.udacity-data.com/nd089/Cat_Dog_data.zip"


response = requests.get(url)


with open('Cat_Dog_data.zip', 'wb') as file:
    file.write(response.content)

with zipfile.ZipFile('Cat_Dog_data.zip', 'r') as zip_ref:
    zip_ref.extractall('data')

train_dir = 'data/Cat_Dog_data/train'

training_dataset = training_data.flow_from_directory(train_dir,target_size=(150,150),batch_size=20,class_mode='binary')
# Out:
# Found 22500 images belonging to 2 classes.

# %%
testing_dir = 'data/Cat_Dog_data/test'

validation_dataset = training_data.flow_from_directory(testing_dir,target_size=(150,150),batch_size=20,class_mode='binary')
# Out:
# Found 2500 images belonging to 2 classes.

# %%
H = my_model.fit_generator(training_dataset, steps_per_epoch=100, epochs=60,validation_data=validation_dataset, validation_steps=50, verbose=2)
# Out:
# <ipython-input-13-b4dfdff29129>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   H = my_model.fit_generator(training_dataset, steps_per_epoch=100, epochs=60,validation_data=validation_dataset, validation_steps=50, verbose=2)
# Epoch 1/60
# 100/100 - 178s - loss: 0.8021 - acc: 0.5505 - val_loss: 0.6658 - val_acc: 0.6300 - 178s/epoch - 2s/step
# Epoch 2/60
# 100/100 - 173s - loss: 0.6662 - acc: 0.6080 - val_loss: 0.6679 - val_acc: 0.6180 - 173s/epoch - 2s/step
# Epoch 3/60
# 100/100 - 166s - loss: 0.6192 - acc: 0.6660 - val_loss: 0.7854 - val_acc: 0.5040 - 166s/epoch - 2s/step
# Epoch 4/60
# 100/100 - 183s - loss: 0.5941 - acc: 0.6880 - val_loss: 0.5814 - val_acc: 0.7040 - 183s/epoch - 2s/step
# Epoch 5/60
# 100/100 - 171s - loss: 0.5695 - acc: 0.7040 - val_loss: 0.5611 - val_acc: 0.6980 - 171s/epoch - 2s/step
# Epoch 6/60
# 100/100 - 172s - loss: 0.5609 - acc: 0.7200 - val_loss: 0.5801 - val_acc: 0.6960 - 172s/epoch - 2s/step
# Epoch 7/60
# 100/100 - 181s - loss: 0.5219 - acc: 0.7375 - val_loss: 0.5556 - val_acc: 0.7130 - 181s/epoch - 2s/step
# Epoch 8/60
# 100/100 - 172s - loss: 0.5177 - acc: 0.7510 - val_loss: 0.5455 - val_acc: 0.7320 - 172s/epoch - 2s/step
# Epoch 9/60
# 100/100 - 177s - loss: 0.5051 - acc: 0.7560 - val_loss: 0.8246 - val_acc: 0.6240 - 177s/epoch - 2s/step
# Epoch 10/60
# 100/100 - 199s - loss: 0.4803 - acc: 0.7670 - val_loss: 0.7864 - val_acc: 0.6590 - 199s/epoch - 2s/step
# Epoch 11/60
# 100/100 - 168s - loss: 0.4704 - acc: 0.7790 - val_loss: 0.5886 - val_acc: 0.7020 - 168s/epoch - 2s/step
# Epoch 12/60
# 100/100 - 172s - loss: 0.4758 - acc: 0.7665 - val_loss: 0.5328 - val_acc: 0.7420 - 172s/epoch - 2s/step
# Epoch 13/60
# 100/100 - 164s - loss: 0.4736 - acc: 0.7795 - val_loss: 0.4973 - val_acc: 0.7670 - 164s/epoch - 2s/step
# Epoch 14/60
# 100/100 - 182s - loss: 0.4521 - acc: 0.7865 - val_loss: 0.5269 - val_acc: 0.7500 - 182s/epoch - 2s/step
# Epoch 15/60
# 100/100 - 172s - loss: 0.4540 - acc: 0.7865 - val_loss: 0.5347 - val_acc: 0.7520 - 172s/epoch - 2s/step
# Epoch 16/60
# 100/100 - 165s - loss: 0.4006 - acc: 0.8300 - val_loss: 0.6237 - val_acc: 0.7310 - 165s/epoch - 2s/step
# Epoch 17/60
# 100/100 - 168s - loss: 0.4112 - acc: 0.8115 - val_loss: 0.4864 - val_acc: 0.7860 - 168s/epoch - 2s/step
# Epoch 18/60
# 100/100 - 168s - loss: 0.3905 - acc: 0.8455 - val_loss: 0.5734 - val_acc: 0.7540 - 168s/epoch - 2s/step
# Epoch 19/60
# 100/100 - 184s - loss: 0.3756 - acc: 0.8305 - val_loss: 0.4774 - val_acc: 0.7700 - 184s/epoch - 2s/step
# Epoch 20/60
# 100/100 - 170s - loss: 0.3856 - acc: 0.8285 - val_loss: 0.5397 - val_acc: 0.7530 - 170s/epoch - 2s/step
# Epoch 21/60
# 100/100 - 163s - loss: 0.3671 - acc: 0.8400 - val_loss: 0.5080 - val_acc: 0.7830 - 163s/epoch - 2s/step
# Epoch 22/60
# 100/100 - 149s - loss: 0.3479 - acc: 0.8520 - val_loss: 0.5361 - val_acc: 0.7430 - 149s/epoch - 1s/step
# Epoch 23/60
# 100/100 - 151s - loss: 0.3353 - acc: 0.8595 - val_loss: 0.5622 - val_acc: 0.7560 - 151s/epoch - 2s/step
# Epoch 24/60
# 100/100 - 147s - loss: 0.3367 - acc: 0.8585 - val_loss: 0.5915 - val_acc: 0.7670 - 147s/epoch - 1s/step
# Epoch 25/60
# 100/100 - 148s - loss: 0.3238 - acc: 0.8625 - val_loss: 0.5716 - val_acc: 0.7590 - 148s/epoch - 1s/step
# Epoch 26/60
# 100/100 - 147s - loss: 0.3021 - acc: 0.8775 - val_loss: 0.5016 - val_acc: 0.7650 - 147s/epoch - 1s/step
# Epoch 27/60
# 100/100 - 152s - loss: 0.2928 - acc: 0.8865 - val_loss: 0.5609 - val_acc: 0.7710 - 152s/epoch - 2s/step
# Epoch 28/60
# 100/100 - 140s - loss: 0.2991 - acc: 0.8755 - val_loss: 0.5198 - val_acc: 0.7640 - 140s/epoch - 1s/step
# Epoch 29/60
# 100/100 - 148s - loss: 0.2790 - acc: 0.8890 - val_loss: 0.6641 - val_acc: 0.7320 - 148s/epoch - 1s/step
# Epoch 30/60
# 100/100 - 149s - loss: 0.2442 - acc: 0.9000 - val_loss: 0.5727 - val_acc: 0.7760 - 149s/epoch - 1s/step
# Epoch 31/60
# 100/100 - 149s - loss: 0.2584 - acc: 0.9015 - val_loss: 0.5600 - val_acc: 0.7580 - 149s/epoch - 1s/step
# Epoch 32/60
# 100/100 - 147s - loss: 0.2545 - acc: 0.9010 - val_loss: 0.5906 - val_acc: 0.7540 - 147s/epoch - 1s/step
# Epoch 33/60
# 100/100 - 149s - loss: 0.2124 - acc: 0.9100 - val_loss: 0.7312 - val_acc: 0.7870 - 149s/epoch - 1s/step
# Epoch 34/60
# 100/100 - 149s - loss: 0.2471 - acc: 0.9020 - val_loss: 0.5790 - val_acc: 0.7620 - 149s/epoch - 1s/step
# Epoch 35/60
# 100/100 - 151s - loss: 0.2193 - acc: 0.9200 - val_loss: 0.5519 - val_acc: 0.7790 - 151s/epoch - 2s/step
# Epoch 36/60
# 100/100 - 150s - loss: 0.2152 - acc: 0.9220 - val_loss: 0.6185 - val_acc: 0.7590 - 150s/epoch - 1s/step
# Epoch 37/60
# 100/100 - 162s - loss: 0.1984 - acc: 0.9300 - val_loss: 0.7420 - val_acc: 0.7790 - 162s/epoch - 2s/step
# Epoch 38/60
# 100/100 - 173s - loss: 0.2054 - acc: 0.9250 - val_loss: 0.6068 - val_acc: 0.7900 - 173s/epoch - 2s/step
# Epoch 39/60
# 100/100 - 168s - loss: 0.1711 - acc: 0.9415 - val_loss: 0.6976 - val_acc: 0.7530 - 168s/epoch - 2s/step
# Epoch 40/60
# 100/100 - 158s - loss: 0.1705 - acc: 0.9420 - val_loss: 0.7629 - val_acc: 0.7730 - 158s/epoch - 2s/step
# Epoch 41/60
# 100/100 - 147s - loss: 0.1833 - acc: 0.9350 - val_loss: 0.6782 - val_acc: 0.7780 - 147s/epoch - 1s/step
# Epoch 42/60
# 100/100 - 140s - loss: 0.1719 - acc: 0.9415 - val_loss: 0.6690 - val_acc: 0.7950 - 140s/epoch - 1s/step
# Epoch 43/60
# 100/100 - 159s - loss: 0.1640 - acc: 0.9435 - val_loss: 0.7024 - val_acc: 0.7680 - 159s/epoch - 2s/step
# Epoch 44/60
# 100/100 - 141s - loss: 0.1324 - acc: 0.9550 - val_loss: 0.8785 - val_acc: 0.7690 - 141s/epoch - 1s/step
# Epoch 45/60
# 100/100 - 148s - loss: 0.1472 - acc: 0.9515 - val_loss: 0.7377 - val_acc: 0.7540 - 148s/epoch - 1s/step
# Epoch 46/60
# 100/100 - 149s - loss: 0.1794 - acc: 0.9400 - val_loss: 0.7226 - val_acc: 0.7710 - 149s/epoch - 1s/step
# Epoch 47/60
# 100/100 - 159s - loss: 0.1426 - acc: 0.9485 - val_loss: 0.6923 - val_acc: 0.7660 - 159s/epoch - 2s/step
# Epoch 48/60
# 100/100 - 143s - loss: 0.1097 - acc: 0.9585 - val_loss: 0.8841 - val_acc: 0.7440 - 143s/epoch - 1s/step
# Epoch 49/60
# 100/100 - 148s - loss: 0.1247 - acc: 0.9615 - val_loss: 0.7060 - val_acc: 0.7990 - 148s/epoch - 1s/step
# Epoch 50/60
# 100/100 - 174s - loss: 0.1112 - acc: 0.9660 - val_loss: 0.7397 - val_acc: 0.7610 - 174s/epoch - 2s/step
# Epoch 51/60
# 100/100 - 171s - loss: 0.1062 - acc: 0.9705 - val_loss: 0.7136 - val_acc: 0.7890 - 171s/epoch - 2s/step
# Epoch 52/60
# 100/100 - 173s - loss: 0.1053 - acc: 0.9690 - val_loss: 0.7988 - val_acc: 0.7830 - 173s/epoch - 2s/step
# Epoch 53/60
# 100/100 - 167s - loss: 0.1057 - acc: 0.9675 - val_loss: 0.9116 - val_acc: 0.7830 - 167s/epoch - 2s/step
# Epoch 54/60
# 100/100 - 175s - loss: 0.0863 - acc: 0.9670 - val_loss: 0.7925 - val_acc: 0.7950 - 175s/epoch - 2s/step
# Epoch 55/60
# 100/100 - 175s - loss: 0.0879 - acc: 0.9705 - val_loss: 0.9465 - val_acc: 0.7730 - 175s/epoch - 2s/step
# Epoch 56/60
# 100/100 - 168s - loss: 0.1074 - acc: 0.9705 - val_loss: 0.8741 - val_acc: 0.7570 - 168s/epoch - 2s/step
# Epoch 57/60
# 100/100 - 172s - loss: 0.0917 - acc: 0.9765 - val_loss: 0.9463 - val_acc: 0.7920 - 172s/epoch - 2s/step
# Epoch 58/60
# 100/100 - 168s - loss: 0.0638 - acc: 0.9795 - val_loss: 1.0191 - val_acc: 0.7910 - 168s/epoch - 2s/step
# Epoch 59/60
# 100/100 - 173s - loss: 0.0940 - acc: 0.9660 - val_loss: 0.8780 - val_acc: 0.7800 - 173s/epoch - 2s/step
# Epoch 60/60
# 100/100 - 178s - loss: 0.0603 - acc: 0.9815 - val_loss: 0.9520 - val_acc: 0.7910 - 178s/epoch - 2s/step

# %%
import matplotlib.pyplot as plt


plt.plot(H.history['acc'], label='training accuracy', marker='o')
plt.plot(H.history['val_acc'], label='validation accuracy', marker='o')

plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('accuracy par epoch')
plt.legend()

plt.show()

# %%
plt.plot(H.history['loss'], label='training loss', marker='o')
plt.plot(H.history['val_loss'], label='validation loss', marker='o')

plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('loss par epoch')
plt.legend()

plt.show()

# %%
predictions = my_model.predict(validation_dataset)
binary_predictions = (predictions > 0.5).astype(int)
cats= sum(binary_predictions == 0)
dogs= sum(binary_predictions == 1)
print("Nombre de chats : " + str(cats) + "Nombre de chiens : " + str(dogs))
# Out:
# 125/125 [==============================] - 38s 302ms/step
# Nombre de chats : [1181]Nombre de chiens : [1319]

# %%
predictions = my_model.predict(validation_dataset)
binary_predictions = (predictions > 0.8).astype(int)
cats= sum(binary_predictions == 0)
dogs= sum(binary_predictions == 1)
print("Nombre de chats : " + str(cats) + "Nombre de chiens : " + str(dogs))
# Out:
# 125/125 [==============================] - 42s 335ms/step
# Nombre de chats : [1320]Nombre de chiens : [1180]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt


predictions = my_model.predict(validation_dataset)

binary_predictions = (predictions > 0.8).astype(int)


true_labels = validation_dataset.classes


cm = confusion_matrix(true_labels, binary_predictions)


class_names = ['Chat', 'Chien']


plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Prediction')
plt.ylabel('données réelle')
plt.show()
# Out:
# 125/125 [==============================] - 38s 305ms/step
